# %%
import json

# %%
with open('latent_dataset_for_llm_training.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

# %%
len(data)
# Out:
# 633

# %%
data[0].keys()
# Out:
# dict_keys(['text', 'predicted_indices'])

# %%
data[0]['text']
# Out:
# 'A room containing 2 tables, a bed and a cabinet.'

# %%
data[0]['predicted_indices']
# Out:
# {'table': [325,
#   1255,
#   325,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   450],
#  'table_2': [325,
#   325,
#   325,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
# ...

# %%
data[0]
# Out:
# {'text': 'A room containing 2 tables, a bed and a cabinet.',
#  'predicted_indices': {'table': [325,
#    1255,
#    325,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    450],
#   'table_2': [325,
#    325,
#    325,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
#    1782,
# ...

# %%
data[0]['predicted_indices']
# Out:
# {'table': [325,
#   1255,
#   325,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   450],
#  'table_2': [325,
#   325,
#   325,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
# ...

# %%
data[0]['predicted_indices'].keys()
# Out:
# dict_keys(['table', 'table_2', 'bed', 'cabinet'])

# %%
data[0]['predicted_indices']['table']
# Out:
# [325,
#  1255,
#  325,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  1782,
#  450]

# %%
type(data[0]['predicted_indices']['table'])
# Out:
# list

# %%
len(data[0]['predicted_indices']['table'])
# Out:
# 64

# %%
len(data[0]['predicted_indices']['table_2'])
# Out:
# 64

# %%
with open('latent_dataset_for_finetuning_v1_tiny_fewshot.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

len(data)
# Out:
# 633

# %%
data[0]
# Out:
# {'instruction': 'You are a 3D scene generator. Given a room description, generate the quantized latent indices for each object mentioned. Each object should be represented by exactly 64 indices from the VQ-VAE codebook (range 0-2047). Output in JSON format with object names as keys and arrays of 64 integers as values. Ensure the output is a *single, unformatted JSON string*.',
# ...

# %%
o = json.loads(data[10]['output'])
o
# Out:
# {'cabinet': [325,
#   1255,
#   756,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   515,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   1782,
#   515,
#   626],
#  'table': [325,
#   1255,
#   108,
#   450,
#   450,
#   450,
#   450,
#   450,
#   450,
#   450,
#   450,
#   1882,
#   450,
#   1882,
#   450,
#   450,
#   450,
#   450,
#   450,
#   450,
#   450,
#   450,
#   450,
#   450,
#   450,
#   450,
#   450,
#   450,
#   450,
#   450,
#   450,
#   450,
#   1882,
#   450,
#   450,
#   450,
#   450,
# ...
